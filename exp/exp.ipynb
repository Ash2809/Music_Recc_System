# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = pd.read_csv("C:\Projects\Music_Recc_System\data\dataset.csv")
dataset.head(5)
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
dataset["track_genre"].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
# ...

# %%
dataset=dataset.drop(columns=["Unnamed: 0","track_id"])

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
dataset.head(5)
# Out:
#                   artists                                         album_name  \
# 0             Gen Hoshino                                             Comedy
# 1            Ben Woodward                                   Ghost (Acoustic)
# 2  Ingrid Michaelson;ZAYN                                     To Begin Again
# 3            Kina Grannis  Crazy Rich Asians (Original Motion Picture Sou...
# 4        Chord Overstreet                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
dataset.drop(columns=["album_name","track_name"],axis=1,inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113999 entries, 0 to 113999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artists           113999 non-null  object
#  1   popularity        113999 non-null  int64
#  2   duration_ms       113999 non-null  int64
#  3   explicit          113999 non-null  bool
#  4   danceability      113999 non-null  float64
#  5   energy            113999 non-null  float64
#  6   key               113999 non-null  int64
#  7   loudness          113999 non-null  float64
#  8   mode              113999 non-null  int64
#  9   speechiness       113999 non-null  float64
#  10  acousticness      113999 non-null  float64
#  11  instrumentalness  113999 non-null  float64
#  12  liveness          113999 non-null  float64
#  13  valence           113999 non-null  float64
#  14  tempo             113999 non-null  float64
#  15  time_signature    113999 non-null  int64
# ...

# %%
dataset["explicit"]=dataset["explicit"].astype(int)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 113999 entries, 0 to 113999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artists           113999 non-null  object
#  1   popularity        113999 non-null  int64
#  2   duration_ms       113999 non-null  int64
#  3   explicit          113999 non-null  int64
#  4   danceability      113999 non-null  float64
#  5   energy            113999 non-null  float64
#  6   key               113999 non-null  int64
#  7   loudness          113999 non-null  float64
#  8   mode              113999 non-null  int64
#  9   speechiness       113999 non-null  float64
#  10  acousticness      113999 non-null  float64
#  11  instrumentalness  113999 non-null  float64
#  12  liveness          113999 non-null  float64
#  13  valence           113999 non-null  float64
#  14  tempo             113999 non-null  float64
#  15  time_signature    113999 non-null  int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dataset["track_genre"]=le.fit_transform(dataset["track_genre"])

# %%
dataset.head(5)
# Out:
#                   artists  popularity  duration_ms  explicit  danceability  \
# 0             Gen Hoshino          73       230666         0         0.676
# 1            Ben Woodward          55       149610         0         0.420
# 2  Ingrid Michaelson;ZAYN          57       210826         0         0.438
# 3            Kina Grannis          71       201933         0         0.266
# 4        Chord Overstreet          82       198853         0         0.618
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  0.4610    1    -6.746     0       0.1430        0.0322          0.000001
# 1  0.1660    1   -17.235     1       0.0763        0.9240          0.000006
# 2  0.3590    0    -9.734     1       0.0557        0.2100          0.000000
# 3  0.0596    0   -18.515     1       0.0363        0.9050          0.000071
# 4  0.4430    2    -9.681     1       0.0526        0.4690          0.000000
#
# ...

# %%
len(dataset["artists"].unique())
# Out:
# 31437

# %%
le=LabelEncoder()
dataset["artists"]=le.fit_transform(dataset["artists"])

# %%
dataset.head()
# Out:
#    artists  popularity  duration_ms  explicit  danceability  energy  key  \
# 0    10357          73       230666         0         0.676  0.4610    1
# 1     3287          55       149610         0         0.420  0.1660    1
# 2    12397          57       210826         0         0.438  0.3590    0
# 3    14839          71       201933         0         0.266  0.0596    0
# 4     5255          82       198853         0         0.618  0.4430    2
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -6.746     0       0.1430        0.0322          0.000001    0.3580
# 1   -17.235     1       0.0763        0.9240          0.000006    0.1010
# 2    -9.734     1       0.0557        0.2100          0.000000    0.1170
# 3   -18.515     1       0.0363        0.9050          0.000071    0.1320
# 4    -9.681     1       0.0526        0.4690          0.000000    0.0829
#
#    valence    tempo  time_signature  track_genre
# ...

# %%
dataset.describe()
# Out:
#              artists     popularity   duration_ms       explicit  \
# count  113999.000000  113999.000000  1.139990e+05  113999.000000
# mean    15749.375626      33.238827  2.280312e+05       0.085501
# std      9077.699993      22.304959  1.072961e+05       0.279627
# min         0.000000       0.000000  8.586000e+03       0.000000
# 25%      7988.000000      17.000000  1.740660e+05       0.000000
# 50%     15609.000000      35.000000  2.129060e+05       0.000000
# 75%     23619.000000      50.000000  2.615060e+05       0.000000
# max     31436.000000     100.000000  5.237295e+06       1.000000
#
#         danceability         energy            key       loudness  \
# count  113999.000000  113999.000000  113999.000000  113999.000000
# mean        0.566801       0.641383       5.309126      -8.258950
# std         0.173543       0.251530       3.559999       5.029357
# min         0.000000       0.000000       0.000000     -49.531000
# ...

# %%
import seaborn as sns
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
model = TSNE(n_components = 2, random_state = 0)
tsne_data = model.fit_transform(dataset.head(1000))
plt.figure(figsize = (7, 7))
plt.scatter(tsne_data[:,0], tsne_data[:,1])
plt.show()

# %%
dataset.hist()
# Out:
# array([[<Axes: title={'center': 'artists'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'duration_ms'}>,
#         <Axes: title={'center': 'explicit'}>],
#        [<Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>,
#         <Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>],
#        [<Axes: title={'center': 'mode'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'acousticness'}>,
#         <Axes: title={'center': 'instrumentalness'}>],
#        [<Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'tempo'}>,
#         <Axes: title={'center': 'time_signature'}>],
#        [<Axes: title={'center': 'track_genre'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)
